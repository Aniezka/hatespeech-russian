# %%
import pandas as pd

# %%
data = pd.read_csv('1_dataset_concatenated.csv')
pd.set_option('display.max_colwidth', None)
data.head(30)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
len(data)
# Out:
# 331279

# %%
data = pd.read_csv('2ch.csv')
len(data)
# Out:
# 256852

# %%
data = pd.read_csv('classic_literature.csv')
len(data)
# Out:
# 14863

# %%
data = pd.read_csv('prodota.csv')
len(data)
# Out:
# 59564
