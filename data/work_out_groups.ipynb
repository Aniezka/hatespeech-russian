# %%
import pandas as pd

# %% [markdown]
# ### Мужчины и женщины

# %%
df_man = pd.read_csv("men_numbers.csv")

# %%
df_man.head()
# Out:
# 0                                 Реплика 1 toxicity  \
# 1   грозненского университета имени ахмата кадыро...
# 3   счетчик в какую сторону работает? в сторону у...
# 4   гандон хуль ты из под шконки верещишь? найду ...
# 6                         зинит ето говно хииххихихи
# 7           еххеххеххе блин а лендлорд нас не побьет
#
# 0                                 Реплика 2 toxicity Результат 1 Результат 2  \
# 1                         извинись сейчас же, гандон       False        True
# 3   на пынинском свинтаке проклятие призрака стар...       False        True
# 4   гандон хуль ты из под шконки верещишь? сказал...        True        True
# 6  э гандоны блять, что вы тут шепчетесь епты? зв...        True        True
# 7  э гандоны блять, что вы тут шепчетесь епты? зв...       False        True
#
# 0     Значение 1  Значение 2  \
# 1  0.00039601803   0.9957157
# 3     0.01690051  0.99550575
# 4     0.99532855  0.99541044
# 6     0.98980373  0.99534893
# ...

# %%
df_man.shape
# Out:
# (4286, 15)

# %%
df_man.describe()
# Out:
#         Unnamed: 0            0
# count  4286.000000  4285.000000
# mean   2142.500000  2142.000000
# std    1237.405956  1237.117281
# min       0.000000     0.000000
# 25%    1071.250000  1071.000000
# 50%    2142.500000  2142.000000
# 75%    3213.750000  3213.000000
# max    4285.000000  4284.000000

# %%
df_man.columns = df_man.iloc[0]

# %%
df_man = df_man.iloc[1:]

# %%
df_man.columns
# Out:
# Index([                   0,                  nan,         'Unnamed: 0',
#        'Реплика 1 toxicity', 'Реплика 2 toxicity',        'Результат 1',
#               'Результат 2',         'Значение 1',         'Значение 2',
#        'Реплика 1 original', 'Реплика 2 original',    'Реплика 2 lemma',
#          'Выделенные слова',       'Многозначное',       'target_group'],
#       dtype='object', name=0)

# %%
del df_man["Unnamed: 0"]

# %%
df_man = pd.DataFrame([x[2: ] for x in df_man.values.tolist()], columns=df_man.columns[2:])

# %%
df_man = df_man[df_man['Многозначное'].notna()]

# %%
del df_man["Многозначное"]

# %%
df_man.to_csv("df_man.csv")

# %%
df_woman = pd.read_csv("women_numbers.csv")

# %%
df_woman.head()
# Out:
#                                    Реплика 1 toxicity  \
# 3   человека все устраивает в жизни и он всем дово...
# 13  nightmaresфига приколньо? твоя типо? молодец т...
# 14  я думал на земле нет таких людей которые смогл...
# 17  rainbow dash ответит на ваши вопросы. лошадь ж...
# 18  я думал на земле нет таких людей которые смогл...
#
#                                    Реплика 2 toxicity  Результат 1  \
# 3   у тебя когда папа видет хуй надроченный у него...        False
# 13  н е просто поржать скинул это дура я ее маму е...        False
# 14  сын шлюхи тупоголовой ненавижу тебя сдохни убл...        False
# 17  а у меня есть блядь с собой пожрать... будешь ...        False
# 18  шлюхи я бы тебе по башкей это калатушкой ебанулбы        False
#
#     Результат 2  Значение 1  Значение 2  \
# 3          True    0.000719    0.997416
# 13         True    0.015077    0.997370
# 14         True    0.001034    0.997353
# 17         True    0.005312    0.997338
# ...

# %%
del df_woman["Unnamed: 0"]

# %%
del df_woman["Unnamed: 0.1"]

# %%
df_woman.describe()
# Out:
#        Значение 1  Значение 2
# count   36.000000   36.000000
# mean     0.365318    0.996985
# std      0.477956    0.000534
# min      0.000314    0.995575
# 25%      0.001034    0.997068
# 50%      0.014396    0.997170
# 75%      0.988230    0.997306
# max      0.997167    0.997416

# %%
df_woman = df_woman[df_woman['Многозначное'].notna()]

# %%
del df_woman["Многозначное"]

# %%
df_woman.to_csv("df_woman.csv")

# %% [markdown]
# ### Все остальные группы

# %%
df_migrant = pd.read_csv("migrant_numbers.csv", sep=";")

# %%
df_migrant.head()
# Out:
#                                    Реплика 1 toxicity  \
# 9   да кидай больше фоток старых ведь они кому то ...
# 13  а протасевич то ветеран. мог бы и героя украин...
# 14   она похожа на мартышку и не говорит по-русски...
# 17   эй, чмондель, так че ты там решил уравнение? ...
# 18  прошлый (op) расписание премьер на ближайшие г...
#
#                                    Реплика 2 toxicity  Результат 1  \
# 9   а щас ты красивая типо ? похудела ? давай вы с...         True
# 13  удивительно как у людей фокус сместился с того...        False
# 14   японки подсознательно с обезьянами ассоциирую...         True
# 17  так а ты решил задачу чмоня? пояснишь почему н...         True
# 18   что это за черножопая обезьяна костюм нацепил...        False
#
#     Результат 2  Значение 1  Значение 2  \
# 9          True    0.982712    0.992344
# 13         True    0.040417    0.992504
# 14        False    0.991323    0.001767
# 17         True    0.970657    0.988853
# ...

# %%
del df_migrant["Unnamed: 0"]

# %%
del df_migrant["Unnamed: 0.1"]

# %%
del df_migrant["Unnamed: 0.1.1"]

# %%
del df_migrant["ipm"]

# %%
df_migrant["target_group"] = ["migrant"] * len(df_migrant)

# %%
df_migrant_new = df_migrant[df_migrant['Другое значение'] == '+'].index
df_migrant.drop(df_migrant_new, inplace = True)

# %%
del df_migrant["Другое значение"]

# %%
df_migrant.describe()
# Out:
#        Значение 1  Значение 2
# count   25.000000   25.000000
# mean     0.364556    0.838490
# std      0.476368    0.355113
# min      0.000286    0.001767
# 25%      0.005193    0.979526
# 50%      0.027354    0.991323
# 75%      0.982712    0.994680
# max      0.996673    0.997219

# %%
df_migrant.to_csv("df_migrant.csv")

# %%
df_lgbt = pd.read_csv("lgbt_numbers.csv", sep=";")

# %%
df_lgbt.head()
# Out:
#                                   Реплика 1 toxicity  \
# 0  ты пока писал блядина сто хуев успел насосать ...
# 1   то есть шлюхи когда делают миниет с праглотом...
# 2  не пиздите на пингвина я вам башню снесу нахуу...
# 3   квартирник провел и кто-то короткий ролик сли...
# 4  и что, ни одного предложения об улучшении секс...
#
#                                   Реплика 2 toxicity  Результат 1  \
# 0  обвафленный хуеплет и сын блядушника и попугая...         True
# 1   ты педераст. пасаны, пизди пидара! петухи взб...         True
# 2  ебанное ничтожное чмо сидящее у мамы на шее (к...         True
# 3   бля, петух ебаный. зашкварен и задеанонен. на...        False
# 4  вы чо блядь твари совсем охуели уже трапов сюд...         True
#
#    Результат 2  Значение 1  Значение 2  \
# 0         True    0.997342    0.997235
# 1         True    0.981134    0.997201
# 2         True    0.991934    0.997197
# 3         True    0.000437    0.997091
# 4         True    0.981827    0.997085
#
# ...

# %%
del df_lgbt["Unnamed: 0"]

# %%
del df_lgbt["Unnamed: 0.1"]

# %%
df_lgbt.rename(columns={"Выделенные слова": "Реплика 2 lemma", "Выделенные слова.1": "Выделенные слова", "Многозначное/другое":"Многозначное"}, inplace = True)

# %%
df_lgbt.columns
# Out:
# Index(['Реплика 1 toxicity', 'Реплика 2 toxicity', 'Результат 1',
#        'Результат 2', 'Значение 1', 'Значение 2', 'Реплика 1 original',
#        'Реплика 2 original', 'Реплика 2 lemma', 'Выделенные слова',
#        'Многозначное', 'target_group'],
#       dtype='object')

# %%
df_lgbt_new = df_lgbt[df_lgbt['Многозначное'] == '+'].index
df_lgbt.drop(df_lgbt_new, inplace = True)

# %%
del df_lgbt["Многозначное"]

# %%
df_lgbt.describe()
# Out:
#        Значение 1  Значение 2
# count  301.000000  301.000000
# mean     0.580253    0.868134
# std      0.467537    0.299952
# min      0.000284    0.000720
# 25%      0.007853    0.969192
# 50%      0.945453    0.989679
# 75%      0.991085    0.995153
# max      0.997342    0.997235

# %%
df_lgbt.to_csv("df_lgbt.csv")

# %%
df_born = pd.read_csv("born_place_numbers.csv", sep=";")

# %%
df_born.head()
# Out:
#                                   Реплика 1 toxicity  \
# 0   бля зоны роста это когда хрящи костей заполня...
# 1  путин просто поставил всю страну на колени, пр...
# 2  в ермолино московской области поймали тигренка...
# 3   пидорашка чужими тик-токами превозмагает, пок...
# 4         бараш пытается сжечь хохла живьем пофиксил
#
#                                   Реплика 2 toxicity  Результат 1  \
# 0  блять уебок ебучий, я тебе сказал нахуй я гото...         True
# 1  моча говно нассал опустил в жопу выебал какие ...        False
# 2  а тем временем хохлы в жопу ебутся надев на го...        False
# 3   тупорылый хуесосник говноед хохол картиночкам...         True
# 4         барин пытается сжечь хохла живьем заебали.         True
#
#    Результат 2  Значение 1  Значение 2  \
# 0         True    0.913245    0.997365
# 1         True    0.113696    0.997252
# 2         True    0.000680    0.997162
# 3         True    0.996995    0.997136
# 4         True    0.989871    0.997129
#
# ...

# %%
del df_born["Unnamed: 0"]

# %%
del df_born["Unnamed: 0.1"]

# %%
df_born_new = df_born[df_born['Многозначное'] == '+'].index
df_born.drop(df_born_new, inplace = True)

# %%
del df_born["Многозначное"]

# %%
df_born.describe()
# Out:
#        Значение 1  Значение 2
# count  551.000000  551.000000
# mean     0.643376    0.791692
# std      0.448546    0.369442
# min      0.000306    0.001370
# 25%      0.022883    0.924041
# 50%      0.976136    0.988652
# 75%      0.992473    0.994189
# max      0.997253    0.997365

# %%
df_born.to_csv("df_born.csv")

# %% [markdown]
# ### Конкатенируем все группы

# %%
others_df = pd.read_csv("others_words.csv")
child_df_one = pd.read_csv("child_matched.csv")
born_place_df_one = pd.read_csv("born_place_matched.csv")
man_df_one = pd.read_csv("man_matched.csv")
migrant_df_one = pd.read_csv("migrant_matched.csv")
lgbt_df_one = pd.read_csv("lgbt_matched.csv")
women_df_one = pd.read_csv("women_matched.csv")

# %%
concatenated_df = pd.concat([
    women_df_one,
    df_woman,
    migrant_df_one,
    df_migrant,
    man_df_one,
    df_man,
    born_place_df_one,
    df_born,
    child_df_one,
    lgbt_df_one,
    df_lgbt,
    others_df
])

# %%
concatenated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13321 entries, 0 to 2104
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          12343 non-null  float64
#  1   Unnamed: 0.1        12343 non-null  float64
#  2   Реплика 1 toxicity  13321 non-null  object
#  3   Реплика 2 toxicity  13321 non-null  object
#  4   Результат 1         13321 non-null  object
#  5   Результат 2         13321 non-null  object
#  6   Значение 1          13321 non-null  object
#  7   Значение 2          13321 non-null  object
#  8   Реплика 1 original  13321 non-null  object
#  9   Реплика 2 original  13321 non-null  object
#  10  Реплика 2 lemma     13321 non-null  object
#  11  Выделенные слова    13321 non-null  object
#  12  target_group        13321 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.4+ MB

# %%
del concatenated_df["Unnamed: 0"]
del concatenated_df["Unnamed: 0.1"]

# %%
concatenated_df.head()
# Out:
#                                   Реплика 1 toxicity  \
# 0   нахуя свинозагонные русофильские пидорюндели ...
# 1   байден подписал законопроект об увеличении в ...
# 2  долбаебы оп сказал про гипоталамус и как задей...
# 3  человека все устраивает в жизни и он всем дово...
# 4  итт я буду восстанавливать сей гениальный опус...
#
#                                   Реплика 2 toxicity Результат 1 Результат 2  \
# 0   да этот загон ебаный надо удалять уже почему ...        True        True
# 1  я маму этого хуяйдена ебал пусть в лицо скажет...       False        True
# 2  гипохуямус, блять, нихуя не понятно... я хочу ...        True        True
# 3  у тебя когда папа видет хуй надроченный у него...       False        True
# 4         еб твою мать блядь иди отсюда нахуй блядь!       False        True
#
#   Значение 1 Значение 2                                 Реплика 1 original  \
# 0   0.994447   0.997482   Нахуя свинозагонные русофильские пидорюндели ...
# ...

# %%
concatenated_df.to_csv("groups_and_slurs.csv", index = False)

# %%
concatenated_df = pd.read_csv("groups_and_slurs.csv")

# %%
concatenated_df.head()
# Out:
#                                   Реплика 1 toxicity  \
# 0   нахуя свинозагонные русофильские пидорюндели ...
# 1   байден подписал законопроект об увеличении в ...
# 2  долбаебы оп сказал про гипоталамус и как задей...
# 3  человека все устраивает в жизни и он всем дово...
# 4  итт я буду восстанавливать сей гениальный опус...
#
#                                   Реплика 2 toxicity  Результат 1  \
# 0   да этот загон ебаный надо удалять уже почему ...         True
# 1  я маму этого хуяйдена ебал пусть в лицо скажет...        False
# 2  гипохуямус, блять, нихуя не понятно... я хочу ...         True
# 3  у тебя когда папа видет хуй надроченный у него...        False
# 4         еб твою мать блядь иди отсюда нахуй блядь!        False
#
#    Результат 2  Значение 1  Значение 2  \
# 0         True    0.994447    0.997482
# 1         True    0.000438    0.997479
# 2         True    0.990614    0.997426
# 3         True    0.000719    0.997416
# 4         True    0.001949    0.997409
#
# ...

# %%
df_ipm = pd.read_csv("groups_slurs_ipm.csv")

# %%
df_ipm.head()
# Out:
#    Unnamed: 0                                 Реплика 1 toxicity  \
# 0         790  яшин опозиция? не позорься дримуха хотя бы с этим
# 1          59   морфеус настоящий со смитом там никогда и не ...
# 2          35   походу они или тупые то ли дело хуй с двачей!...
# 3        1470   мне удавалось висеть до полутора минут за под...
# 4         456  крона стресс...у масквичей уже реально едет кр...
#
#                                   Реплика 2 toxicity  Результат 1  \
# 0  в чем трабл, опять что-то не так может зюганов...        False
# 1   это был бы явный перебор по выдавленной носта...        False
# 2  я ценю твою постиронию. но подумай сам, что, б...         True
# 3   может быть и сукой , но более точный перевод ...        False
# 4  так вы москали поганые дайте свободу россии, н...        False
#
#    Результат 2  Значение 1  Значение 2  \
# 0         True    0.189031    0.995042
# 1         True    0.002118    0.997134
# 2         True    0.995897    0.997206
# ...
